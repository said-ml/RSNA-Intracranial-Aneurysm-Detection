# %%
import torch
from torch.utils.data import Dataset, DataLoader

class PatchDataset(Dataset):
      def __int__(self,
                  volume,
                  patch_size =(16, 256, 256),
                  patch_per_volume = 10,
                  patch_overlap = 0.5,
                  patch_stride = 1,):
          pass
# Out:
# 20
